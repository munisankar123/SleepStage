# %% [markdown]
# <a href="https://colab.research.google.com/github/munisankar123/SleepStage/blob/main/multichanneldatapreparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyedflib
# !pip install pywavelets
# Out:
# Collecting pyedflib
#   Downloading pyEDFlib-0.1.38-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pyedflib) (1.26.4)
# Downloading pyEDFlib-0.1.38-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 51.8 MB/s eta 0:00:00
# Installing collected packages: pyedflib
# Successfully installed pyedflib-0.1.38
# Collecting pywavelets
#   Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from pywavelets) (1.26.4)
# Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 64.5 MB/s eta 0:00:00
# Installing collected packages: pywavelets
# Successfully installed pywavelets-1.7.0

# %%
import pyedflib
import numpy as np
import pandas as pd
edf_path = '/content/drive/MyDrive/database/n3.edf'
edf_file = pyedflib.EdfReader(edf_path)
edf_labels=edf_file.getSignalLabels()
edf_labels
# Out:
# ['Fp2-F4',
#  'F4-C4',
#  'C4-P4',
#  'P4-O2',
#  'F8-T4',
#  'T4-T6',
#  'FP1-F3',
#  'F3-C3',
#  'C3-P3',
#  'P3-O1',
#  'F7-T3',
#  'T3-T5',
#  'C4-A1',
#  'ROC-LOC',
#  'EMG1-EMG2',
#  'ECG1-ECG2',
#  'DX1-DX2',
#  'SX1-SX2',
#  'SAO2',
#  'HR',
#  'PLETH',
#  'STAT',
#  'MIC']

# %%
[signal1,signal2,signal3,signal4,signal5]=[edf_file.readSignal(0),edf_file.readSignal(1),edf_file.readSignal(2),edf_file.readSignal(3),edf_file.readSignal(12)]

# %%
annotations_file = pd.read_csv('/content/drive/MyDrive/database/n3.csv')
annotations_file
# Out:
#      Sleep_Stage Time_[hh:mm:ss]     Event  Duration[s]    Location
# 0              W        23:06:12  SLEEP-S0           30     ROC-LOC
# 1              W        23:06:42  SLEEP-S0           30     ROC-LOC
# 2             S1        23:07:12  SLEEP-S1           30     ROC-LOC
# 3             S1        23:07:24   MCAP-A3            3  EEG-Fp2-F4
# 4             S1        23:07:30   MCAP-A3            3  EEG-Fp2-F4
# ...          ...             ...       ...          ...         ...
# 1349           W        07:24:12  SLEEP-S0           30     ROC-LOC
# 1350           W        07:24:42  SLEEP-S0           30     ROC-LOC
# 1351           W        07:25:12  SLEEP-S0           30     ROC-LOC
# 1352           W        07:25:42  SLEEP-S0           30     ROC-LOC
# 1353           W        07:26:12  SLEEP-S0           30     ROC-LOC
#
# [1354 rows x 5 columns]

# %%
starttime = 0
fs = 512
labeled_segments = []

# Assuming you have 7 channels
signaldata = [edf_file.readSignal(0),edf_file.readSignal(1),edf_file.readSignal(2),edf_file.readSignal(3),edf_file.readSignal(12)]

for idx, row in annotations_file.iterrows():
    duration = row['Duration[s]']
    endtime = starttime + (fs * duration)
    if endtime <= len(signaldata[0]):
        if duration == 30:

            segment = {f'Signal_{i+1}': signal[starttime:endtime] for i, signal in enumerate(signaldata)}
            segment['Sleep_Stage'] = row['Sleep_Stage']
            labeled_segments.append(segment)
        starttime = endtime
    else:
        break


data = pd.DataFrame(labeled_segments)
data
# Out:
#                                               Signal_1  \
# 0    [-6.944444444444445, -8.318070818070817, -10.8...
# 1    [24.526862026862027, 24.374236874236875, 24.16...
# 2    [-16.46825396825397, -10.576923076923077, 1.63...
# 3    [4.9603174603174605, 4.441391941391942, 4.1971...
# 4    [10.729548229548229, 10.82112332112332, 10.882...
# ..                                                 ...
# 994  [-10.21062271062271, -10.912698412698413, -11....
# 995  [-0.3205128205128205, 0.1984126984126984, 0.80...
# 996  [0.10683760683760683, -0.0763125763125763, -0....
# 997  [1.9688644688644688, 1.572039072039072, 1.0836...
# 998  [-8.44017094017094, -8.531746031746032, -8.531...
#
#                                               Signal_2  \
# 0    [-3.556166056166056, -2.02991452991453, 0.2594...
# 1    [6.181318681318682, 5.7234432234432235, 5.3266...
# 2    [-3.250915750915751, -3.0982905982905984, -4.4...
# 3    [4.838217338217338, 4.868742368742368, 4.74664...
# 4    [3.159340659340659, 2.487789987789988, 1.81623...
# ..                                                 ...
# 994  [-3.5866910866910864, -3.891941391941392, -4.1...
# 995  [4.990842490842491, 4.685592185592186, 4.44139...
# 996  [3.9529914529914527, 3.7698412698412698, 3.434...
# 997  [-0.992063492063492, -1.1446886446886446, -1.3...
# 998  [2.090964590964591, 2.213064713064713, 2.30463...
#
#                                               Signal_3  \
# 0    [0.6562881562881563, 1.4194139194139195, 2.609...
# 1    [1.6636141636141635, 1.2667887667887667, 0.686...
# 2    [5.418192918192918, 5.387667887667887, 4.96031...
# 3    [7.066544566544566, 7.4633699633699635, 7.9212...
# 4    [5.906593406593406, 5.326617826617826, 4.77716...
# ..                                                 ...
# 994  [3.3424908424908426, 3.556166056166056, 3.7393...
# 995  [4.014041514041514, 3.5866910866910864, 3.0067...
# 996  [2.3351648351648353, 2.457264957264957, 2.4877...
# 997  [-4.197191697191697, -4.38034188034188, -4.502...
# 998  [11.187423687423687, 10.973748473748474, 10.63...
#
#                                               Signal_4  \
# 0    [-1.5415140415140414, -2.7625152625152625, -4....
# 1    [-2.1214896214896215, -2.3351648351648353, -2....
# 2    [-4.624542124542124, -4.594017094017094, -4.25...
# 3    [-6.12026862026862, -5.692918192918193, -4.960...
# 4    [9.325396825396824, 8.37912087912088, 7.310744...
# ..                                                 ...
# 994  [-0.6562881562881563, 0.10683760683760683, 0.8...
# 995  [3.0982905982905984, 2.731990231990232, 2.2741...
# 996  [1.7857142857142856, 2.457264957264957, 3.2509...
# 997  [-5.479242979242979, -5.479242979242979, -5.41...
# 998  [7.738095238095238, 8.073870573870574, 8.34859...
#
#                                               Signal_5 Sleep_Stage
# 0    [-4.9603174603174605, -8.531746031746032, -11....           W
# 1    [14.545177045177045, 9.691697191697191, 5.6013...           W
# 2    [4.38034188034188, 7.158119658119658, 8.653846...          S1
# 3    [-1.3278388278388278, 0.25946275946275943, 0.7...          S1
# 4    [106.6086691086691, 109.47802197802197, 111.37...          S1
# ..                                                 ...         ...
# 994  [14.514652014652015, 17.048229548229546, 19.49...           W
# 995  [13.995726495726496, 13.385225885225886, 12.46...           W
# 996  [11.340048840048839, 12.072649572649572, 13.01...           W
# 997  [-1.2057387057387057, -1.0836385836385836, -0....           W
# 998  [23.977411477411476, 23.55006105006105, 22.725...           W
#
# [999 rows x 6 columns]

# %%
num_segments = len(labeled_segments)
print(f"Number of segments extracted: {num_segments}")
num_30_sec_durations = annotations_file[annotations_file['Duration[s]'] == 30].shape[0]
print(f"Number of 30-second durations: {num_30_sec_durations}")
# Out:
# Number of segments extracted: 999
# Number of 30-second durations: 999

# %%
stages = data['Sleep_Stage']

eegdata = data.drop(columns=['Sleep_Stage'])

# %%
def reshape_matrix_to_row(matrix):
    return matrix.flatten()
reshaped_data1 = eegdata['Signal_1'].apply(lambda x: pd.Series(reshape_matrix_to_row(x)))
reshaped_data1 = reshaped_data1.reset_index(drop=True)
reshaped_data1
# Out:
#          0          1          2          3          4          5      \
# 0    -6.944444  -8.318071 -10.882173 -13.782051 -16.559829 -19.032357
# 1    24.526862  24.374237  24.160562  23.977411  23.885836  23.672161
# 2   -16.468254 -10.576923   1.633089  12.255800  15.338828  18.086081
# 3     4.960317   4.441392   4.197192   4.197192   4.380342   4.868742
# 4    10.729548  10.821123  10.882173  10.729548  10.393773  10.180098
# ..         ...        ...        ...        ...        ...        ...
# 994 -10.210623 -10.912698 -11.523199 -12.133700 -12.744200 -13.324176
# 995  -0.320513   0.198413   0.808913   1.510989   2.335165   3.220391
# 996   0.106838  -0.076313  -0.442613  -0.839438  -1.236264  -1.602564
# 997   1.968864   1.572039   1.083639   0.503663  -0.076313  -0.564713
# 998  -8.440171  -8.531746  -8.531746  -8.379121  -8.012821  -7.554945
#
#          6          7          8          9      ...      15350      15351  \
# 0   -21.108059 -22.847985 -24.221612 -25.289988  ...  27.579365  27.701465
# 1    23.244811  22.878510  23.061661  23.702686  ...  14.575702   5.448718
# 2    27.029915  32.799145  25.564713   9.081197  ...  -6.639194  -6.700244
# 3     5.815018   7.097070   8.012821   8.012821  ...  11.278999  10.973748
# 4     9.996947   9.661172   8.989621   8.348596  ...  19.520757  21.382784
# ..         ...        ...        ...        ...  ...        ...        ...
# 994 -13.812576 -14.087302 -14.117827 -14.056777  ...  -6.303419  -5.876068
# 995   4.166667   5.051893   5.845543   6.486569  ...  -2.609890  -2.213065
# 996  -1.999389  -2.396215  -2.823565  -3.189866  ...   0.045788   0.289988
# 997  -0.869963  -1.053114  -1.083639  -0.961538  ...  -7.982295  -7.799145
# 998  -7.127595  -6.730769  -6.333944  -5.906593  ...   0.595238   0.412088
#
#          15352      15353      15354      15355      15356      15357  \
# 0    27.365690  26.694139  25.961538  25.534188  25.412088  25.228938
# 1    -1.938339  -3.189866  -1.175214  -1.388889  -5.418193 -11.156899
# 2    -7.066545  -7.677045  -8.440171  -9.294872 -10.027473 -10.637973
# 3    10.821123  10.882173  10.973748  10.943223  10.851648  10.790598
# 4    23.611111  26.541514  29.380342  31.242369  31.425519  29.838217
# ..         ...        ...        ...        ...        ...        ...
# 994  -5.235043  -4.532967  -3.830891  -3.189866  -2.579365  -1.968864
# 995  -1.816239  -1.419414  -1.022589  -0.656288  -0.320513  -0.045788
# 996   0.564713   0.839438   1.175214   1.572039   1.907814   2.090965
# 997  -7.615995  -7.493895  -7.463370  -7.554945  -7.768620  -7.951770
# 998   0.351038   0.320513   0.259463   0.259463   0.259463   0.076313
#
#          15358      15359
# 0    24.832112  24.587912
# 1   -15.338828 -16.987179
# 998   1.419414   1.236264   0.900488   0.534188   0.045788  -0.442613
#
#          15359
# 0    -2.304640
# 1    -4.563492
# 2     1.297314
# 3    10.149573
# 4     0.076313
# ..         ...
# 994   3.281441
# 995   1.236264
# 996  -5.479243
# 997   7.280220
# 998  -0.900488
#
# [999 rows x 15360 columns]

# %%
reshaped_data3 = eegdata['Signal_3'].apply(lambda x: pd.Series(reshape_matrix_to_row(x)))
reshaped_data3 = reshaped_data3.reset_index(drop=True)
reshaped_data3
# Out:
#          0          1          2          3         4         5         6      \
# 0     0.656288   1.419414   2.609890   3.952991  5.265568  6.517094  7.585470
# 1     1.663614   1.266789   0.686813   0.137363 -0.228938 -0.442613 -0.625763
# 2     5.418193   5.387668   4.960317   4.380342  3.800366  3.006716  1.602564
# 3     7.066545   7.463370   7.921245   8.379121  8.684371  8.806471  8.684371
# 4     5.906593   5.326618   4.777167   4.319292  4.044567  3.891941  3.800366
# ..         ...        ...        ...        ...       ...       ...       ...
# 994   3.342491   3.556166   3.739316   3.952991  4.227717  4.471917  4.685592
# 995   4.014042   3.586691   3.006716   2.365690  1.755189  1.327839  1.022589
# 996   2.335165   2.457265   2.487790   2.487790  2.670940  2.976190  3.250916
# 997  -4.197192  -4.380342  -4.502442  -4.471917 -4.319292 -3.983516 -3.495116
# 998  11.187424  10.973748  10.637973  10.088523  9.386447  8.623321  7.860195
#
#         7         8         9      ...      15350      15351      15352  \
# 0    8.470696  9.111722  9.539072  ...   1.388889   1.297314   1.205739
# 1   -0.808913 -1.053114 -1.388889  ...   0.473138   1.297314   1.785714
# 2    0.015263 -0.992063 -1.175214  ...   0.381563   0.259463   0.137363
# 3    8.318071  7.860195  7.432845  ...   7.524420   7.921245   8.287546
# 4    3.891941  4.014042  4.075092  ...   1.205739   0.717338   0.076313
# ..        ...       ...       ...  ...        ...        ...        ...
# 994  4.899267  5.051893  5.235043  ...   3.342491   3.647741   3.952991
# 995  0.717338  0.381563  0.045788  ...   0.289988   0.534188   0.839438
# 996  3.464591  3.617216  3.739316  ...  -2.304640  -2.426740  -2.701465
# 997 -3.006716 -2.640415 -2.274115  ...  11.614774  11.828449  11.889499
# 998  7.158120  6.456044  5.784493  ...  -0.778388  -0.900488  -0.961538
#
#          15353      15354      15355      15356      15357      15358  \
# 0     1.083639   0.961538   0.992063   1.266789   1.602564   1.785714
# 1     1.938339   2.152015   2.579365   3.159341   3.800366   4.410867
# 2     0.015263  -0.198413  -0.595238  -0.961538  -1.297314  -1.633089
# 3     8.714896   8.898046   8.653846   8.104396   7.554945   7.036020
# 4    -0.595238  -0.961538  -0.717338  -0.076313   0.595238   1.114164
# ..         ...        ...        ...        ...        ...        ...
# 994   4.197192   4.410867   4.594017   4.746642   4.746642   4.594017
# 995   1.083639   1.236264   1.388889   1.572039   1.785714   1.999389
# 996  -2.976190  -3.189866  -3.342491  -3.434066  -3.525641  -3.678266
# 997  11.920024  11.889499  11.828449  11.736874  11.675824  11.584249
# 998  -0.992063  -0.961538  -0.931013  -0.900488  -0.869963  -0.778388
#
#          15359
# 0     1.816239
# 1     5.021368
# 2    -1.999389
#
# [999 rows x 15360 columns]

# %%
reshaped_data5 = eegdata['Signal_5'].apply(lambda x: pd.Series(reshape_matrix_to_row(x)))
reshaped_data5 = reshaped_data5.reset_index(drop=True)
reshaped_data5
# Out:
#           0           1           2           3           4           5      \
# 0     -4.960317   -8.531746  -11.920024  -14.942002  -17.353480  -18.971306
# 1     14.545177    9.691697    5.601343    5.570818    8.928571   12.683150
# 2      4.380342    7.158120    8.653846    9.661172   11.248474   13.293651
# 3     -1.327839    0.259463    0.778388   -1.633089   -5.601343   -8.623321
# 4    106.608669  109.478022  111.370574  112.683150  113.812576  114.545177
# ..          ...         ...         ...         ...         ...         ...
# 994   14.514652   17.048230   19.490232   21.626984   23.336386   24.557387
# 995   13.995726   13.385226   12.469475   11.340049   10.027473    8.501221
# 996   11.340049   12.072650   13.018926   14.087302   15.125153   16.040904
# 997   -1.205739   -1.083639   -0.778388   -0.289988    0.259463    0.808913
# 998   23.977411   23.550061   22.725885   21.443834   19.795482   17.963980
#
#           6           7           8           9      ...      15350  \
# 0    -19.673382  -19.490232  -18.666056  -17.567155  ...   4.319292
# 1     16.010379   18.116606   18.666056   18.940781  ... -21.749084
# 2     15.949328   21.535409   30.692918   41.346154  ... -21.382784
# 3     -8.806471   -3.891941    5.448718   14.484127  ...  93.543956
# 4    113.995726  111.828449  109.233822  107.921245  ...  40.583028
# ..          ...         ...         ...         ...  ...        ...
# 994   25.351038   25.625763   25.473138   25.045788  ...  15.674603
# 995    6.852869    5.143468    3.617216    2.579365  ...  19.001832
# 996   16.804029   17.384005   17.902930   18.543956  ...  -6.120269
# 997    0.839438    0.381563    0.076313    0.137363  ...  25.564713
# 998   15.857753   13.385226   10.943223    9.020147  ... -11.126374
#
#          15351      15352      15353      15354      15355      15356  \
# 0     8.104396  10.576923  12.255800  14.209402  16.346154  18.482906
# 1   -24.954212 -26.358364 -26.480464 -25.656288 -23.275336 -18.605006
# 2   -17.139805 -13.690476 -11.217949  -8.104396  -4.899267  -3.159341
# 3    95.985958  95.650183  92.414530  88.568376  86.797924  88.324176
# 4    39.117827  29.105617  13.232601  -4.044567 -18.757631 -28.220391
# ..         ...        ...        ...        ...        ...        ...
# 994  15.155678  15.003053  15.064103  15.186203  15.247253  15.186203
# 995  15.369353  11.981074  10.149573   9.600122   9.661172   9.905372
# 996  -5.204518  -4.349817  -3.525641  -2.793040  -2.243590  -1.785714
# 997  25.259463  25.106838  25.045788  25.045788  24.984737  24.740537
# 998 -10.821123 -10.821123 -10.943223 -11.095849 -11.248474 -11.920024
#
#          15357      15358       15359
# 0    20.009158  19.917582   18.025031
# 1   -12.377900  -5.967643    0.015263
# 2    -3.586691  -3.647741   -0.961538
# 3    92.597680  97.817460  102.640415
# 4   -31.303419 -31.425519  -31.974969
# ..         ...        ...         ...
# 994  14.942002  14.575702   14.300977
# 995  10.149573  10.424298   10.790598
# 996  -1.480464  -1.327839   -1.297314
# 997  24.465812  24.282662   24.160562
# 998 -13.324176 -14.453602  -14.819902
#
# [999 rows x 15360 columns]

# %%
from scipy.signal import butter, filtfilt
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return b, a
def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = filtfilt(b, a, data, axis=0)
    return y
lowcut = 0.2
highcut = 30.0
fs = 512
x_bal_np1 = reshaped_data1.to_numpy()
x_bal_filtered1 = np.apply_along_axis(lambda x: butter_bandpass_filter(x, lowcut, highcut, fs), axis=1, arr=x_bal_np1)
x_bal_filtered1 = pd.DataFrame(x_bal_filtered1)


x_bal_np2 = reshaped_data2.to_numpy()
x_bal_filtered2 = np.apply_along_axis(lambda x: butter_bandpass_filter(x, lowcut, highcut, fs), axis=1, arr=x_bal_np2)
x_bal_filtered2 = pd.DataFrame(x_bal_filtered2)


x_bal_np3 = reshaped_data3.to_numpy()
x_bal_filtered3 = np.apply_along_axis(lambda x: butter_bandpass_filter(x, lowcut, highcut, fs), axis=1, arr=x_bal_np3)
x_bal_filtered3 = pd.DataFrame(x_bal_filtered3)


x_bal_np4 = reshaped_data4.to_numpy()
x_bal_filtered4 = np.apply_along_axis(lambda x: butter_bandpass_filter(x, lowcut, highcut, fs), axis=1, arr=x_bal_np4)
x_bal_filtered4 = pd.DataFrame(x_bal_filtered4)


x_bal_np5 = reshaped_data5.to_numpy()
x_bal_filtered5 = np.apply_along_axis(lambda x: butter_bandpass_filter(x, lowcut, highcut, fs), axis=1, arr=x_bal_np5)
x_bal_filtered5 = pd.DataFrame(x_bal_filtered5)

# %%
x_bal_1 = x_bal_filtered1
y_bal_1 = stages
segment_duration = 2
sampling_rate = 512
segment_length = segment_duration * sampling_rate
segments = []
labels = []
x_bal_1=np.array(x_bal_1)
y_bal_1=np.array(y_bal_1)
for i, signal in enumerate(x_bal_1):
    for start in range(0, len(signal) - segment_length + 1, segment_length):
        segment = signal[start:start + segment_length]
        segments.append(segment)
        labels.append(y_bal_1[i])
segments_np = np.array(segments)
labels_np = np.array(labels)
two_segments = pd.DataFrame(segments_np)
two_labels = pd.DataFrame(labels_np, columns=['label'])
df1 = pd.concat([two_segments, two_labels], axis=1)
df1
# Out:
#                   0             1             2             3             4  \
# 0      1.413547e+40  1.409017e+40  1.404501e+40  1.399999e+40  1.395511e+40
# 1      5.306496e+38  5.289520e+38  5.272599e+38  5.255731e+38  5.238918e+38
# 2      2.131426e+37  2.124732e+37  2.118059e+37  2.111407e+37  2.104777e+37
# 3      8.606864e+35  8.580375e+35  8.553969e+35  8.527645e+35  8.501404e+35
# 4      3.475795e+34  3.464680e+34  3.453600e+34  3.442554e+34  3.431543e+34
# ...             ...           ...           ...           ...           ...
# 14980 -8.796874e+25 -8.768851e+25 -8.740915e+25 -8.713068e+25 -8.685308e+25
# 14981 -3.336953e+24 -3.326372e+24 -3.315825e+24 -3.305311e+24 -3.294831e+24
# 14982 -1.306102e+23 -1.301954e+23 -1.297819e+23 -1.293698e+23 -1.289589e+23
# 14983 -5.122580e+21 -5.106402e+21 -5.090272e+21 -5.074189e+21 -5.058155e+21
# 14984 -2.919340e+20 -2.909025e+20 -2.898711e+20 -2.888396e+20 -2.878082e+20
#
#                   5             6             7             8             9  \
# 0      1.391037e+40  1.386578e+40  1.382133e+40  1.377701e+40  1.373284e+40
# 1      5.222159e+38  5.205453e+38  5.188800e+38  5.172201e+38  5.155656e+38
# 2      2.098167e+37  2.091579e+37  2.085011e+37  2.078464e+37  2.071938e+37
# 3      8.475244e+35  8.449166e+35  8.423169e+35  8.397253e+35  8.371418e+35
# 4      3.420566e+34  3.409624e+34  3.398716e+34  3.387842e+34  3.377003e+34
# ...             ...           ...           ...           ...           ...
# 14980 -8.657635e+25 -8.630049e+25 -8.602550e+25 -8.575137e+25 -8.547810e+25
# 14981 -3.284384e+24 -3.273970e+24 -3.263589e+24 -3.253241e+24 -3.242926e+24
# 14982 -1.285494e+23 -1.281411e+23 -1.277342e+23 -1.273285e+23 -1.269242e+23
# 14983 -5.042168e+21 -5.026228e+21 -5.010336e+21 -4.994491e+21 -4.978693e+21
# 14984 -2.867768e+20 -2.857455e+20 -2.847142e+20 -2.836830e+20 -2.826518e+20
#
#        ...          1015          1016          1017          1018  \
# 0      ...  5.461751e+38  5.444279e+38  5.426863e+38  5.409502e+38
# 1      ...  2.192643e+37  2.185754e+37  2.178887e+37  2.172042e+37
# 2      ...  8.849031e+35  8.821786e+35  8.794625e+35  8.767550e+35
# 3      ...  3.577415e+34  3.565982e+34  3.554584e+34  3.543223e+34
# 4      ...  1.415662e+33  1.411292e+33  1.406935e+33  1.402591e+33
# ...    ...           ...           ...           ...           ...
# 14980  ... -3.433711e+24 -3.422823e+24 -3.411969e+24 -3.401150e+24
# 14981  ... -1.344039e+23 -1.339769e+23 -1.335514e+23 -1.331272e+23
# 14982  ... -5.270363e+21 -5.253747e+21 -5.237181e+21 -5.220663e+21
# 14983  ... -3.012182e+20 -3.001866e+20 -2.991550e+20 -2.981234e+20
# 14984  ... -4.740403e+19 -4.620806e+19 -4.498912e+19 -4.374618e+19
#
#                1019          1020          1021          1022          1023  \
# 0      5.392196e+38  5.374946e+38  5.357751e+38  5.340612e+38  5.323527e+38
# 1      2.165219e+37  2.158417e+37  2.151637e+37  2.144879e+37  2.138142e+37
# 2      8.740559e+35  8.713652e+35  8.686830e+35  8.660091e+35  8.633436e+35
# 3      3.531897e+34  3.520606e+34  3.509351e+34  3.498131e+34  3.486945e+34
# 4      1.398261e+33  1.393944e+33  1.389640e+33  1.385349e+33  1.381071e+33
# ...             ...           ...           ...           ...           ...
# 14980 -3.390365e+24 -3.379615e+24 -3.368898e+24 -3.358216e+24 -3.347568e+24
# 14981 -1.327043e+23 -1.322828e+23 -1.318627e+23 -1.314438e+23 -1.310264e+23
# 14982 -5.204194e+21 -5.187774e+21 -5.171403e+21 -5.155080e+21 -5.138806e+21
# 14983 -2.970918e+20 -2.960602e+20 -2.950286e+20 -2.939971e+20 -2.929655e+20
# 14984 -4.247912e+19 -4.118899e+19 -3.987806e+19 -3.854984e+19 -3.720882e+19
#
#        label
# 0          W
# 1          W
# 2          W
# 3          W
# 4          W
# ...      ...
# 14980      W
# 14981      W
# 14982      W
# 14983      W
# 14984      W
#
# [14985 rows x 1025 columns]

# %%
x_bal_2 = x_bal_filtered2
y_bal_1 = stages
segment_duration = 2
sampling_rate = 512
segment_length = segment_duration * sampling_rate
segments = []
labels = []
x_bal_2=np.array(x_bal_2)
y_bal_1=np.array(y_bal_1)
for i, signal in enumerate(x_bal_2):
    for start in range(0, len(signal) - segment_length + 1, segment_length):
        segment = signal[start:start + segment_length]
        segments.append(segment)
        labels.append(y_bal_1[i])
segments_np = np.array(segments)
labels_np = np.array(labels)
two_segments = pd.DataFrame(segments_np)
two_labels = pd.DataFrame(labels_np, columns=['label'])
df2 = pd.concat([two_segments, two_labels], axis=1)
df2
# Out:
#                   0             1             2             3             4  \
# 0     -6.514122e+39 -6.493532e+39 -6.473007e+39 -6.452547e+39 -6.432152e+39
# 1     -2.559490e+38 -2.551460e+38 -2.543457e+38 -2.535479e+38 -2.527527e+38
# 2     -1.068813e+37 -1.065478e+37 -1.062154e+37 -1.058840e+37 -1.055536e+37
# 3     -4.394491e+35 -4.380597e+35 -4.366747e+35 -4.352941e+35 -4.339179e+35
# 4     -1.755125e+34 -1.749620e+34 -1.744133e+34 -1.738663e+34 -1.733210e+34
# ...             ...           ...           ...           ...           ...
# 14980 -4.125508e+24 -4.113038e+24 -4.100607e+24 -4.088212e+24 -4.075855e+24
# 14981 -1.677655e+23 -1.672240e+23 -1.666842e+23 -1.661460e+23 -1.656096e+23
# 14982 -6.681744e+21 -6.660979e+21 -6.640278e+21 -6.619641e+21 -6.599069e+21
# 14983 -2.625286e+20 -2.616522e+20 -2.607786e+20 -2.599078e+20 -2.590398e+20
# 14984 -1.431823e+19 -1.426854e+19 -1.421886e+19 -1.416919e+19 -1.411951e+19
#
#                   5             6             7             8             9  \
# 0     -6.411821e+39 -6.391554e+39 -6.371351e+39 -6.351213e+39 -6.331138e+39
# 1     -2.519600e+38 -2.511698e+38 -2.503822e+38 -2.495971e+38 -2.488145e+38
# 2     -1.052243e+37 -1.048960e+37 -1.045688e+37 -1.042425e+37 -1.039173e+37
# 3     -4.325461e+35 -4.311786e+35 -4.298154e+35 -4.284566e+35 -4.271021e+35
# 4     -1.727775e+34 -1.722357e+34 -1.716956e+34 -1.711573e+34 -1.706207e+34
# ...             ...           ...           ...           ...           ...
# 14980 -4.063535e+24 -4.051252e+24 -4.039006e+24 -4.026796e+24 -4.014624e+24
# 14981 -1.650748e+23 -1.645417e+23 -1.640102e+23 -1.634804e+23 -1.629523e+23
# 14982 -6.578560e+21 -6.558115e+21 -6.537733e+21 -6.517415e+21 -6.497159e+21
# 14983 -2.581746e+20 -2.573122e+20 -2.564526e+20 -2.555957e+20 -2.547415e+20
# 14984 -1.406984e+19 -1.402017e+19 -1.397051e+19 -1.392085e+19 -1.387119e+19
#
#        ...          1015          1016          1017          1018  \
# 0      ... -2.632922e+38 -2.624657e+38 -2.616420e+38 -2.608208e+38
# 1      ... -1.099301e+37 -1.095871e+37 -1.092451e+37 -1.089042e+37
# 2      ... -4.521547e+35 -4.507250e+35 -4.492998e+35 -4.478791e+35
# 3      ... -1.805472e+34 -1.799806e+34 -1.794158e+34 -1.788528e+34
# 4      ... -7.526765e+32 -7.503170e+32 -7.479649e+32 -7.456203e+32
# ...    ...           ...           ...           ...           ...
# 14980  ... -1.727154e+23 -1.721585e+23 -1.716034e+23 -1.710500e+23
# 14981  ... -6.871556e+21 -6.850204e+21 -6.828917e+21 -6.807696e+21
# 14982  ... -2.705438e+20 -2.696418e+20 -2.687426e+20 -2.678463e+20
# 14983  ... -1.476551e+19 -1.471580e+19 -1.466610e+19 -1.461639e+19
# 14984  ... -2.232492e+18 -2.176188e+18 -2.118801e+18 -2.060283e+18
#
#                1019          1020          1021          1022          1023  \
# 0     -2.600023e+38 -2.591864e+38 -2.583732e+38 -2.575625e+38 -2.567544e+38
# 1     -1.085644e+37 -1.082257e+37 -1.078880e+37 -1.075514e+37 -1.072158e+37
# 2     -4.464629e+35 -4.450512e+35 -4.436440e+35 -4.422413e+35 -4.408430e+35
# 3     -1.782916e+34 -1.777323e+34 -1.771747e+34 -1.766188e+34 -1.760648e+34
# 4     -7.432831e+32 -7.409533e+32 -7.386309e+32 -7.363159e+32 -7.340082e+32
# ...             ...           ...           ...           ...           ...
# 14980 -1.704983e+23 -1.699483e+23 -1.694001e+23 -1.688535e+23 -1.683086e+23
# 14981 -6.786541e+21 -6.765451e+21 -6.744427e+21 -6.723467e+21 -6.702573e+21
# 14982 -2.669529e+20 -2.660624e+20 -2.651747e+20 -2.642898e+20 -2.634078e+20
# 14983 -1.456669e+19 -1.451700e+19 -1.446730e+19 -1.441761e+19 -1.436792e+19
# 14984 -2.000628e+18 -1.939885e+18 -1.878162e+18 -1.815623e+18 -1.752480e+18
#
#        label
# 0          W
# 1          W
# 2          W
# 3          W
# 4          W
# ...      ...
# 14980      W
# 14981      W
# 14982      W
# 14983      W
# 14984      W
#
# [14985 rows x 1025 columns]

# %%
x_bal_3 = x_bal_filtered3
y_bal_1 = stages
segment_duration = 2
sampling_rate = 512
segment_length = segment_duration * sampling_rate
segments = []
labels = []
x_bal_3=np.array(x_bal_3)
y_bal_1=np.array(y_bal_1)
for i, signal in enumerate(x_bal_3):
    for start in range(0, len(signal) - segment_length + 1, segment_length):
        segment = signal[start:start + segment_length]
        segments.append(segment)
        labels.append(y_bal_1[i])
segments_np = np.array(segments)
labels_np = np.array(labels)
two_segments = pd.DataFrame(segments_np)
two_labels = pd.DataFrame(labels_np, columns=['label'])
df3 = pd.concat([two_segments, two_labels], axis=1)

# %%
x_bal_5 = x_bal_filtered5
y_bal_1 = stages
segment_duration = 2
sampling_rate = 512
segment_length = segment_duration * sampling_rate
segments = []
labels = []
x_bal_5=np.array(x_bal_5)
y_bal_1=np.array(y_bal_1)
for i, signal in enumerate(x_bal_5):
    for start in range(0, len(signal) - segment_length + 1, segment_length):
        segment = signal[start:start + segment_length]
        segments.append(segment)
        labels.append(y_bal_1[i])
segments_np = np.array(segments)
labels_np = np.array(labels)
two_segments = pd.DataFrame(segments_np)
two_labels = pd.DataFrame(labels_np, columns=['label'])
df5 = pd.concat([two_segments, two_labels], axis=1)
df5
# Out:
#                   0             1             2             3             4  \
# 0      1.046462e+40  1.043181e+40  1.039912e+40  1.036653e+40  1.033404e+40
# 1      4.216185e+38  4.202762e+38  4.189382e+38  4.176045e+38  4.162751e+38
# 14980  1.129144e+25  1.125557e+25  1.121982e+25  1.118417e+25  1.114864e+25
# 14981  4.704458e+23  4.689812e+23  4.675212e+23  4.660657e+23  4.646148e+23
# 14982  1.914382e+22  1.908165e+22  1.901968e+22  1.895790e+22  1.889631e+22
# 14983  1.074582e+21  1.070937e+21  1.067292e+21  1.063648e+21  1.060005e+21
# 14984  1.405674e+20  1.362976e+20  1.319591e+20  1.275634e+20  1.231254e+20
#
#        label
# 0          W
# 1          W
# 2          W
# 3          W
# 4          W
# ...      ...
# 14980      W
# 14981      W
# 14982      W
# 14983      W
# 14984      W
#
# [14985 rows x 1025 columns]

# %%
x_bal_4 = x_bal_filtered4
y_bal_1 = stages
segment_duration = 2
sampling_rate = 512
segment_length = segment_duration * sampling_rate
segments = []
labels = []
x_bal_4=np.array(x_bal_4)
y_bal_1=np.array(y_bal_1)
for i, signal in enumerate(x_bal_4):
    for start in range(0, len(signal) - segment_length + 1, segment_length):
        segment = signal[start:start + segment_length]
        segments.append(segment)
        labels.append(y_bal_1[i])
segments_np = np.array(segments)
labels_np = np.array(labels)
two_segments = pd.DataFrame(segments_np)
two_labels = pd.DataFrame(labels_np, columns=['label'])
df4 = pd.concat([two_segments, two_labels], axis=1)

# %%
df4
# Out:
#                   0             1             2             3             4  \
# 0      5.792915e+39  5.774733e+39  5.756608e+39  5.738541e+39  5.720531e+39
# 1      2.380548e+38  2.373149e+38  2.365773e+38  2.358419e+38  2.351088e+38
# 2      9.331138e+36  9.302954e+36  9.274857e+36  9.246845e+36  9.218919e+36
# 3      3.827588e+35  3.815433e+35  3.803316e+35  3.791238e+35  3.779198e+35
# 4      1.494697e+34  1.490131e+34  1.485579e+34  1.481042e+34  1.476519e+34
# ...             ...           ...           ...           ...           ...
# 14980  1.396900e+26  1.392640e+26  1.388393e+26  1.384160e+26  1.379940e+26
# 14981  5.756782e+24  5.738723e+24  5.720721e+24  5.702775e+24  5.684886e+24
# 14982  2.219019e+23  2.212033e+23  2.205069e+23  2.198127e+23  2.191207e+23
# 14983  8.567525e+21  8.539241e+21  8.511043e+21  8.482932e+21  8.454908e+21
# 14984  4.447879e+20  4.432386e+20  4.416893e+20  4.401403e+20  4.385913e+20
#
#                   5             6             7             8             9  \
# 0      5.702578e+39  5.684682e+39  5.666843e+39  5.649060e+39  5.631333e+39
# 1      2.343780e+38  2.336494e+38  2.329230e+38  2.321990e+38  2.314771e+38
# 2      9.191078e+36  9.163323e+36  9.135652e+36  9.108065e+36  9.080563e+36
# 3      3.767197e+35  3.755233e+35  3.743308e+35  3.731420e+35  3.719571e+35
# 4      1.472011e+34  1.467517e+34  1.463037e+34  1.458571e+34  1.454120e+34
# ...             ...           ...           ...           ...           ...
# 14980  1.375734e+26  1.371540e+26  1.367361e+26  1.363194e+26  1.359041e+26
# 14981  5.667052e+24  5.649275e+24  5.631553e+24  5.613886e+24  5.596275e+24
# 14982  2.184309e+23  2.177433e+23  2.170579e+23  2.163746e+23  2.156935e+23
# 14983  8.426971e+21  8.399119e+21  8.371354e+21  8.343674e+21  8.316080e+21
# 14984  4.370426e+20  4.354939e+20  4.339455e+20  4.323972e+20  4.308491e+20
#
#        ...          1015          1016          1017          1018  \
# 0      ...  2.448182e+38  2.440574e+38  2.432989e+38  2.425428e+38
# 1      ...  9.588725e+36  9.559751e+36  9.530866e+36  9.502070e+36
# 2      ...  3.938743e+35  3.926235e+35  3.913766e+35  3.901337e+35
# 3      ...  1.536453e+34  1.531754e+34  1.527070e+34  1.522401e+34
# 4      ...  6.340880e+32  6.320533e+32  6.300250e+32  6.280032e+32
# ...    ...           ...           ...           ...           ...
# 14980  ...  5.921884e+24  5.903308e+24  5.884790e+24  5.866331e+24
# 14981  ...  2.282902e+23  2.275714e+23  2.268548e+23  2.261405e+23
# 14982  ...  8.826050e+21  8.796970e+21  8.767980e+21  8.739078e+21
# 14983  ...  4.587382e+20  4.571877e+20  4.556373e+20  4.540870e+20
# 14984  ...  6.971284e+19  6.795339e+19  6.616021e+19  6.433177e+19
#
#                1019          1020          1021          1022          1023  \
# 0      2.417890e+38  2.410375e+38  2.402884e+38  2.395416e+38  2.387971e+38
# 1      9.473362e+36  9.444743e+36  9.416211e+36  9.387766e+36  9.359409e+36
# 2      3.888948e+35  3.876598e+35  3.864287e+35  3.852015e+35  3.839782e+35
# 3      1.517747e+34  1.513107e+34  1.508483e+34  1.503873e+34  1.499277e+34
# 4      6.259877e+32  6.239787e+32  6.219760e+32  6.199797e+32  6.179897e+32
# ...             ...           ...           ...           ...           ...
# 14980  5.847929e+24  5.829585e+24  5.811299e+24  5.793069e+24  5.774897e+24
# 14981  2.254284e+23  2.247186e+23  2.240111e+23  2.233058e+23  2.226027e+23
# 14982  8.710265e+21  8.681541e+21  8.652905e+21  8.624357e+21  8.595898e+21
# 14983  4.525368e+20  4.509868e+20  4.494369e+20  4.478871e+20  4.463375e+20
# 14984  6.246790e+19  6.057014e+19  5.864183e+19  5.668814e+19  5.471565e+19
#
#        label
# 0          W
# 1          W
# 2          W
# 3          W
# 4          W
# ...      ...
# 14980      W
# 14981      W
# 14982      W
# 14983      W
# 14984      W
#
# [14985 rows x 1025 columns]

# %%
import os
import pandas as pd

# Assuming df1, df2, df3, df4, df5 are already loaded
dataframes = [df1, df2, df3, df4, df5]
output_dir = "/content/drive/MyDrive"


class_names = ['W', 'S1', 'S2', 'S3', 'S4', 'R']


for class_name in class_names:
    class_dir = os.path.join(output_dir, class_name)
    os.makedirs(class_dir, exist_ok=True)


for i in range(len(df1)):

    label = df1.iloc[i, -1]
    row_df1 = df1.iloc[i, :-1].to_frame().T
    row_df2 = df2.iloc[i, :-1].to_frame().T
    row_df3 = df3.iloc[i, :-1].to_frame().T
    row_df4 = df4.iloc[i, :-1].to_frame().T
    row_df5 = df5.iloc[i, :-1].to_frame().T


    combined_df = pd.concat([row_df1, row_df2, row_df3, row_df4, row_df5], ignore_index=True)

    class_dir = os.path.join(output_dir, label)
    output_file = os.path.join(class_dir, f"{label}_{i+1}.csv")

    combined_df.to_csv(output_file, index=False, header=False)

print("Files generated successfully and organized into folders!")
# Out:
# Files generated successfully and organized into folders!
